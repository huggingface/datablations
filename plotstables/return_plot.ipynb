# %% [markdown]
# #### Data loading

# %%
### DATA POINTS ###

# Read from the Log / TensorBoard of "val" designated folder of each model on the hub
NAMES_TO_VAL_LOSSES = {
    "2b84b4b": 3.265024E+00,
    "2b88b4b": 2.995093E+00,
    "2b812b4b": 2.884387E+00,
    "2b816b4b": 2.823208E+00,
    "2b824b4b": 2.752407E+00,
    "2b832b4b": 2.722962E+00,
    "2b840b4b": 2.706547E+00,
    
    # "2b855b4bc4optv1": 2.700284E+00,
    # "2b855b9boptv1": 2.632432E+00,
    # "2b855b9bc4opt2": 2.609009E+00
    # "2b855b4bc4opt2": 2.689857E+00,
    # "2b855b4bc4opt3": 2.692264E+00

    "2b855b11bc4seed1": 2.599277E+00,
    "2b855b11bc4seed2": 2.599763E+00,
    "2b855b11bc4seed3": 2.600254E+00,
    "2b855b11bc4seed4": 2.598042E+00,

    "2b855b14bc4seed1": 2.592292E+00,
    "2b855b14bc4seed2": 2.590478E+00,
    "2b855b14bc4seed3": 2.588968E+00,
    "2b855b14bc4seed4": 2.591426E+00,

    "2b855b18bc4seed1": 2.582283E+00,
    "2b855b18bc4seed2": 2.581189E+00,
    "2b855b18bc4seed3": 2.584074E+00,
    "2b855b18bc4seed4": 2.581949E+00,

    "2b855b1b25c4seed1": 3.425332E+00,
    "2b855b1b25c4seed2": 3.422794E+00,
    "2b855b1b25c4seed3": 3.425154E+00,
    "2b855b1b25c4seed4": 3.428524E+00,


    "2b855b28bc4seed1": 2.575713E+00,
    "2b855b28bc4seed2": 2.576707E+00,
    "2b855b28bc4seed3": 2.574265E+00,
    "2b855b28bc4seed4": 2.575176E+00,

    "2b855b4bc4seed1": 2.693317E+00,
    "2b855b4bc4seed2": 2.691274E+00,
    "2b855b4bc4seed3": 2.692641E+00,
    "2b855b4bc4seed4": 2.692532E+00,

    "2b855b55bc4seed1": 2.569702E+00,
    "2b855b55bc4seed2": 2.568221E+00,
    "2b855b55bc4seed3": 2.569587E+00,
    "2b855b55bc4seed4": 2.570589E+00,

    "2b855b9bc4seed1": 2.609228E+00,
    "2b855b9bc4seed2": 2.605090E+00,
    "2b855b9bc4seed3": 2.605155E+00,
    "2b855b9bc4seed4": 2.606114E+00,

    #"2b855b55bperplexity": 2.604075E+00
    #"2b855b55bdedup": 2.758145E+00,
    #"2b855b55bc4perplexity25": 2.740080E+00, 
    #"2b855b55bc4perplexity50": 2.659265E+00

    # "2b884b84bperplexity25": 2.701157E+00
    # "2b884b84bperplexity50": 2.636081E+00
    # "2b884b84bperplexity2575": 2.612976E+00


    "2b855b1b25": 3.422766E+00,
    "2b855b4b": 2.696432E+00,
    "2b855b9b": 2.611045E+00,
    "2b855b11b": 2.598793E+00,
    "2b855b14b": 2.589427E+00,
    "2b855b18b": 2.584592E+00,
    "2b855b28b": 2.579361E+00,
    "2b855b55b": 2.574117E+00,

    "4b212b12b": 2.848890E+00,
    "4b224b12b": 2.691483E+00,
    "4b236b12b": 2.618343E+00,
    "4b248b12b": 2.577519E+00,
    "4b260b12b": 2.560390E+00,
    "4b272b12b": 2.539524E+00,

    # "4b284b12bsubopt": 2.562510E+00,
    # "4b284b6bsubopt": 2.650107E+00, # Probably worse cuz loss midway goes up (verify in graph)
    # "4b284b12bopt": 2.525244E+00,
    # "4b284b6bopt": 2.641864E+00
    "4b284b12bc4opt4": 2.520537E+00,

    "4b284b12bseed1": 2.538173E+00,
    "4b284b12bc4seed2": 2.526042E+00,
    "4b284b12bc4seed3": 2.537281E+00,
    "4b284b12bc4seed4": 2.527790E+00,

    "4b284b17bc4seed1": 2.549558E+00,
    "4b284b17bc4seed2": 2.503345E+00,
    "4b284b17bc4seed3": 2.499933E+00,
    "4b284b17bc4seed4": 2.496040E+00,

    "4b284b1b9c4seed1": 3.118388E+00,
    "4b284b1b9c4seed2": 3.082603E+00,
    "4b284b1b9c4seed3": 3.111291E+00,
    "4b284b1b9c4seed4": 3.146578E+00,

    "4b284b21bc4seed1": 2.502885E+00,
    "4b284b21bc4seed2": 2.480593E+00,
    "4b284b21bc4seed3": 2.491781E+00,
    "4b284b21bc4seed4": 2.477816E+00,

    "4b284b28bc4seed1": 2.479697E+00,
    "4b284b28bc4seed2": 2.482804E+00,
    "4b284b28bc4seed3": 2.477427E+00,
    "4b284b28bc4seed4": 2.494708E+00,

    "4b284b42bc4seed1": 2.470463E+00,
    "4b284b42bc4seed2": 2.491261E+00,
    "4b284b42bc4seed3": 2.469242E+00,
    "4b284b42bc4seed4": 2.469873E+00,

    "4b284b84bc4v2seed1": 2.464149E+00,
    "4b284b84bc4v2seed2": 2.461136E+00,
    "4b284b84bc4v2seed3": 2.480773E+00,
    "4b284b84bc4v2seed4": 2.476263E+00,

    "4b284b6bseed1": 2.602034E+00, 
    "4b284b6bseed2": 2.604310E+00,
    "4b284b6bseed3": 2.609000E+00,
    "4b284b6bseed4": 2.614594E+00,

    #"4b284b84b10c4py": 2.813708E+00,
    #"4b284b84b20c4py": 2.683304E+00
    #"4b284b84b30c4py": 2.613236E+00,
    #"4b284b84b40c4py": 2.568575E+00,
    #"4b284b84b50c4py": 2.535289E+00,
    #"4b284b84b60c4py": 2.509820E+00,
    #"4b284b84b70c4py": 2.491829E+00,
    #"4b284b84b80c4py": 2.479359E+00,
    #"4b284b84b90c4py": 2.462060E+00,

    # "4b284bc4perplexity": 2.496036E+00,
    # "4b284bc4perplexity25": 2.624402E+00,
    # "4b284bc4perplexity50": 2.539634E+00
    # "4b284bc4dedup": 2.687236E+00,

    "4b284b1b9": 3.276627E+00,
    "4b284b6b": 2.639410E+00,
    "4b284b12b": 2.526961E+00,
    "4b284b17b": 2.485060E+00,
    "4b284b21b": 2.471375E+00,
    "4b284b28b": 2.467156E+00,
    "4b284b42b": 2.470016E+00,
    "4b284b84b": 2.456530E+00,

    "8b7178b25b": 2.376484E+00,
    "8b7178b35b": 2.360029E+00,
    "8b7178b44b": 2.351177E+00,
    "8b7178b58b": 2.348107E+00,
    "8b7178b88b": 2.337275E+00,
    "8b7178b178b": 2.336741E+00,

    "7m100m100m": 8.107364E+00, # MassiveW optimal one
    "7m200m100m": 7.362360E+00,

    "1b1100m100m": 6.611002E+00,
    "2b8100m100m": 7.518863E+00,

    "14m100m100m": 7.278144E+00, # C4 optimal one
    "20m400m400m": 6.096268E+00,
    "25m400m400m": 5.794130E+00, # MassiveW optimal one
    
    "25m200m100m": 6.252892E+00,
    "25m400m100m": 5.799587E+00,
    "25m800m100m": 5.284175E+00,

    "14m200m100m": 6.664138E+00,
    "14m400m100m": 6.273184E+00,
    "14m800m100m": 5.816824E+00,

    "14m1b5100m": 5.364749E+00,
    "14m2b7100m": 4.992776E+00,
    "14m3b9100m": 4.741132E+00,
    "14m5b9100m": 4.546227E+00,
    "14m7b5100m": 4.472296E+00,
    "14m14b100m": 4.383392E+00,
    "14m20b100m": 4.510410E+00, ### DOUBLE DESCENT ###
    "14m91b100m": 4.396074E+00,
    "14m174b100m": 4.359691E+00,
    "14m300b100m": 4.369110E+00, ### DOUBLE DESCENT ###
    "14m600b100m": 4.331469E+00,
    "14m900b100m": 4.304018E+00, # 3362566

    "44m200m100m": 6.189970E+00,
    "44m400m100m": 5.648868E+00,

    "44m1b5100m": 4.387672E+00,
    "44m2b7100m": 4.113597E+00,
    "44m3b9100m": 3.988205E+00,
    "44m5b9100m": 3.894340E+00,
    "44m7b5100m": 3.854261E+00,
    "44m14b100m": 3.807672E+00,
    "44m20b100m": 3.929030E+00, ### DOUBLE DESCENT ###
    "44m32b100m": 3.892240E+00,
    "44m91b100m": 3.836200E+00,
    "44m174b100m": 3.812315E+00,

    "83m1b51b5": 4.362080E+00, # MassiveW optimal one

    "196m1b51b5": 3.929866E+00, # C4 optimal one

    "1b11b51b5": 3.680017E+00,
    "1b11b5400m": 3.704141E+00,
    "1b11b5100m": 3.819042E+00,

    "1b12b7100m": 4.097820E+00,
    "1b13b9100m": 4.834920E+00,
    "1b15b9100m": 6.013517E+00,
    "1b17b5100m": 6.742290E+00,

    "619m2b72b7": 3.415532E+00,
    "619m2b71b5": 3.409955E+00,
    "619m2b7400m": 3.449187E+00,
    "619m2b7100m": 3.829336E+00,

    "619m1b5100m": 3.784308E+00,
    "619m3b9100m": 4.152834E+00,
    "619m5b9100m": 4.668028E+00,
    "619m7b5100m": 5.001218E+00,

    "421m3b93b9": 3.348126E+00,
    "421m3b91b5": 3.354960E+00,
    "421m3b9400m": 3.404755E+00,
    "421m3b9100m": 3.898620E+00,

    "421m1b5100m": 3.797898E+00,
    "421m2b7100m": 3.747371E+00,
    "421m5b9100m": 4.169935E+00,
    "421m7b5100m": 4.376178E+00,

    "280m5b95b9": 3.319542E+00,
    "280m5b91b5": 3.330755E+00,
    "280m5b9400m": 3.386692E+00,
    "280m5b9100m": 3.882211E+00,

    "280m1b5100m": 3.877228E+00,
    "280m2b7100m": 3.727590E+00,
    "280m3b9100m": 3.754965E+00,
    "280m7b5100m": 3.993410E+00,
    "280m91b400m": 3.312059E+00,

    "220m7b57b5": 3.310159E+00,
    "220m7b51b5": 3.325092E+00,
    "220m7b5400m": 3.374362E+00,
    "220m7b5100m": 3.848433E+00,

    "220m1b5100m": 3.932167E+00,
    "220m2b7100m": 3.752793E+00,
    "220m3b9100m": 3.721901E+00,
    "220m5b9100m": 3.780970E+00,

    "220m3b9100mdedup": 3.863982E+00,

    "146m14b14b": 3.319729E+00,
    "146m14b1b5": 3.334061E+00,
    "146m14b400m": 3.390927E+00,
    "146m14b100m": 3.801428E+00, ### DOUBLE DESCENT

    "146m60b400m": 3.340250E+00,
    "146m91b400m": 3.311519E+00,
    "146m174b400m": 3.277013E+00,

    "146m1b5100m": 4.033501E+00,
    "146m2b7100m": 3.807640E+00,
    "146m3b9100m": 3.732758E+00,
    "146m5b9100m": 3.718068E+00, # To FLOPS: 6 * 146M * 5.9B = 5.0622e+18
    "146m7b5100m": 3.735044E+00,
    "146m20b100m": 3.756257E+00,
    "146m32b100m": 3.793078E+00,
    "146m60b100m": 3.846421E+00,
    "146m91b100m": 3.862952E+00,
    "146m174b100m": 3.897418E+00,

    "146m1b5100mdedup": 4.169387E+00,
    "146m2b7100mdedup": 3.949182E+00,
    "146m3b9100mdedup": 3.871975E+00,
    "146m5b9100mdedup": 3.860607E+00,
    "146m7b5100mdedup": 3.883653E+00,
    "146m14b100mdedup": 3.963449E+00, # WEAK DOUBLE DESCENT
    "146m32b100mdedup": 3.962464E+00,
    "146m60b100mdedup": 4.017775E+00,
    "146m91b100mdedup": 4.065124E+00,
    "146m174b100mdedup": 4.094653E+00,

    "83m20b20b": 3.608018E+00,
    "83m20b1b5": 3.618937E+00,
    "83m20b400m": 3.651057E+00,
    "83m20b100m": 3.790125E+00, ### DOUBLE DESCENT ###

    "83m400m100m": 5.488318E+00,
    "83m1b5100m": 4.206960E+00,
    "83m2b7100m": 3.953894E+00,
    "83m3b9100m": 3.844048E+00,
    "83m5b9100m": 3.774708E+00,
    "83m7b5100m": 3.747734E+00,
    "83m14b100m": 3.725231E+00,
    "83m32b100m": 3.747091E+00,
    "83m60b100m": 3.747091E+00,
    "83m91b100m": 3.743505E+00,
    "83m174b100m": 3.734349E+00,
    "83m300b100m": 3.868704E+00,

    "83m14b100mdedup": 3.872943E+00,

    "2b84b84b8": 3.236253E+00,
    "2b84b81b5": 3.244249E+00,
    "2b84b8400m": 3.378791E+00,
    "2b84b8100m": 5.340819E+00,

    "1b58b88b8": 3.022525E+00,
    "1b58b84b8": 3.022745E+00,
    "1b58b81b5": 3.070052E+00,
    "1b58b8400m": 3.479142E+00,
    "1b58b8100m": 7.679766E+00,

    "1b112b12b": 2.925644E+00,
    "1b112b4b8": 2.927054E+00,
    "1b112b1b5": 2.996886E+00,
    "1b112b400m": 3.547616E+00,
    "1b112b100m": 8.136283E+00,

    "619m22b22b": 2.900172E+00,
    "619m22b4b8": 2.912009E+00,
    "619m22b1b5": 2.973545E+00, # To FLOPS: 6 * 619M * 22B = 8.1708e+19
    "619m22b400m": 3.441785E+00,
    "619m22b100m": 6.840158E+00,

    "619m60b400m": 3.688865E+00,
    "619m91b400m": 3.756154E+00,

    "421m32b32b": 2.912103E+00,
    "421m32b4b8": 2.926206E+00,
    "421m32b1b5": 2.980892E+00,
    "421m32b400m": 3.366502E+00,
    "421m32b100m": 5.783605E+00,

    "421m60b400m": 3.431953E+00,
    "421m91b400m": 3.465185E+00,

    "421m91b1b5": 2.917592E+00,
    "421m250b1b5": 2.890927E+00,
    "421m300b1b5": 2.884335E+00,

    "221m60b60b": 2.981407E+00,
    "221m60b4b8": 2.993185E+00, 
    "221m60b1b5": 3.032319E+00,
    "221m60b400m": 3.258704E+00,

    "221m3b9400m": 3.525297E+00, # 3427121
    "221m32b400m": 3.260515E+00,
    "221m91b400m": 3.261209E+00,
    "221m174b400m": 3.260720E+00,
    "221m300b400m": 3.257426E+00,
    "221m600b400m": 3.261908E+00, # 3427134

    "8b712b12b": 3.140306E+00,
    "8b712b1b5": 3.063302E+00,
    "8b712b400m": 4.538278E+00,
    "8b712b100m": 7.385309E+00,

    "3b926b26b": 2.916993E+00,
    "3b926b12b": 2.947956E+00,
    "3b926b1b5": 3.020170E+00,
    "3b926b400m": 0, # 3325633 || 3417346 || 3417449
    "3b926b100m": 0, # 3328544 || 3417450

    "2b836b36b": 2.618932E+00,
    "2b836b12b": 2.636968E+00,
    "2b836b1b5": 3.065092E+00,
    "2b836b400m": 6.548141E+00,
    "2b836b100m": 1.069564E+01,

    "2b246b46b": 2.603919E+00,
    "2b246b12b": 2.638341E+00,
    "2b246b1b5": 3.029574E+00,
    "2b246b400m": 5.896346E+00,
    "2b246b100m": 1.087606E+01,

    "1b566b66b": 2.592968E+00,
    "1b566b12b": 2.626113E+00,
    "1b566b1b5": 2.992921E+00,
    "1b566b400m": 0,
    "1b566b100m": 1.101838E+01,

    "1b191b91b": 2.636805E+00, ####
    "1b191b12b": 2.665932E+00, ####
    "1b191b400m": 4.618763E+00,
    "1b191b1b5": 2.939082E+00,

    "574m174b174b": 2.708514E+00,
    "574m174b12b": 2.738098E+00,
    "574m174b1b5": 2.895393E+00,
    "574m174b400m": 3.752652E+00,

    "220m200b1b5": 0, # Run 3329133 3329460 | 3361359
    "220m250b1b5": 0, # Run 3329465 | 3361350
    "220m300b1b5": 2.958765E+00, # 3319369 3329472 | 3361340
    "220m600b1b5": 2.937761E+00,
    "220m900b1b5": 0, # 3327278 3329479 | 3361319

    "574m200b1b5": 0, # Run | 3361309
    "574m250b1b5": 0, # Run 3319364 | 3361298
    "574m300b1b5": 2.881076E+00,
    "574m600b1b5": 2.863888E+00, # 3327301 | 3361285 (short) ||| 3420530

    "1b1174b1b5": 2.974257E+00, # Run
    "1b1250b1b5": 2.986145E+00,

    "1b591b1b5": 3.034805E+00,
    "1b5174b1b5": 3.099245E+00,

    "2b266b1b5": 0, # Run > 3325408
    "2b291b1b5": 3.176858E+00,
    "2b2174b1b5": 3.351022E+00,

    "8b720b1b5": 3.084724E+00,
    "2b877b1b5": 3.297776E+00,

}

TOKENS_MAP = {
    "100m": 0.1,
    "200m": 0.2,
    "400m": 0.4,
    "800m": 0.8,
    "1b25": 1.25,
    "1b5": 1.5,
    "1b9": 1.9,
    "2b7": 2.7,
    "2b8": 2.8,
    "3b9": 3.9,
    "5b9": 5.9,
    "7b5": 7.5,
    "14b": 14,
    "20b": 20,
    "174b": 174,    
}

PARAMS_MAP = {
    "7m": 7.098752E+06,
    "14m": 1.41E+07,
    "20m": 19.703712E+06,
    "25m": 35.5E+06,
    "44m": 4.4E+07,
    "83m": 8.27E+07,    
    "146m": 1.465E+08,
    "196m": 201.236224E+06,
    "220m": 2.205E+08,
    "221m": 2.205E+08,
    "280m": 2.81E+08,
    "421m": 4.212E+08,
    "574m": 573.7E+06,
    "619m": 6.187E+08,
    "1b1": 1.0963E+09,     
    "1b5": 1.5173E+09,
    "2b2": 2.160013824E+09,
    "2b8": 2.81E+09,    
    "3b8": 3.581186048E+09, # 3802M
    "3b9": 3.89971072E+09,
    "4b2": 4.2465E+09,
    "8b7": 8.67E+09,
}

# %%
import numpy as np
import matplotlib.pyplot as plt

model_params = []
tokens = []
unique_tokens = []
losses = []
names = []

def get_params(name):
    idx = 2
    while name[:idx] not in PARAMS_MAP:
        idx += 1
    params = PARAMS_MAP[name[:idx]]

    return params, idx


def get_unique_tokens(name):
    idx = -4 if (name[-1] in ("b", "m")) or ((name[-1] not in ("b", "m")) and (name[-2] not in ("b", "m"))) else -3
    ut = name[idx:]
    while (ut.count("b") > 1) or (ut.count("m") > 1):
        idx += 1
        ut = name[idx:]
    if ut in TOKENS_MAP:
        ut = TOKENS_MAP[ut]
    else:
        ut = float(ut.replace("b", ".").strip("."))
    
    if name == "2b855b1b25":
      print(name[idx:])

    return ut * 1e9, idx

def get_tokens(tokens):
    if tokens in TOKENS_MAP:
        tokens = TOKENS_MAP[tokens]
    else:
        tokens = float(tokens.replace("b", ".").strip("."))

    return tokens * 1e9 # Defined in billions

for name, loss in NAMES_TO_VAL_LOSSES.items():
    if loss != 0 and not(name.endswith("dedup")) and not("seed" in name) and not("opt" in name):
        p, tok_start_idx = get_params(name)
        ut, tok_end_idx = get_unique_tokens(name)
        t = get_tokens(name[tok_start_idx:tok_end_idx])

        model_params.append(p)
        unique_tokens.append(ut)
        tokens.append(t)
        losses.append(loss)

        names.append(name)

        print(name, p, t, ut, loss)
# Out:
# 2b84b4b 2810000000.0 4000000000.0 4000000000.0 3.265024
# 2b88b4b 2810000000.0 8000000000.0 4000000000.0 2.995093
# 2b812b4b 2810000000.0 12000000000.0 4000000000.0 2.884387
# 2b816b4b 2810000000.0 16000000000.0 4000000000.0 2.823208
# 2b824b4b 2810000000.0 24000000000.0 4000000000.0 2.752407
# 2b832b4b 2810000000.0 32000000000.0 4000000000.0 2.722962
# 2b840b4b 2810000000.0 40000000000.0 4000000000.0 2.706547
# 1b25
# 2b855b1b25 2810000000.0 55000000000.0 1250000000.0 3.422766
# 2b855b4b 2810000000.0 55000000000.0 4000000000.0 2.696432
# 2b855b9b 2810000000.0 55000000000.0 9000000000.0 2.611045
# 2b855b11b 2810000000.0 55000000000.0 11000000000.0 2.598793
# 2b855b14b 2810000000.0 55000000000.0 14000000000.0 2.589427
# 2b855b18b 2810000000.0 55000000000.0 18000000000.0 2.584592
# 2b855b28b 2810000000.0 55000000000.0 28000000000.0 2.579361
# 2b855b55b 2810000000.0 55000000000.0 55000000000.0 2.574117
# 4b212b12b 4246500000.0 12000000000.0 12000000000.0 2.84889
# ...

# %%
for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names):
    if ut > t:
        raise ValueError(n)

# %% [markdown]
# #### Plot

# %%
### CHINCHILLA ###

import numpy as np

a, b, e, alpha, beta = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068] # C4
# a, b, e, alpha, beta = [6.007337896264272, 6.016157159698354, 0.5247285289349821, 0.34, 0.28] # MW

A = np.exp(a)
B = np.exp(b)
E = np.exp(e)
G = ((alpha*A)/(beta*B))**(1/(alpha+beta))

def optimal_N(C):
    a = (beta)/(alpha+beta)
    N_opt = G*(C/6)**a
    return N_opt

def N_to_C(N):
    a = (beta)/(alpha+beta)
    C = ((N/G) ** (1/a)) * 6
    return C
  
def optimal_D(C):
    b = (alpha)/(alpha+beta)
    D_opt = (1/G)*(C/6)**b
    return D_opt

def D_to_C(D):
    b = (alpha)/(alpha+beta)
    C = ((G*D) ** (1/b)) * 6
    return C

def loss_fn(N, D):
    L = E + A/(N**alpha) + B/(D**beta)
    return L

# %%
func = r"$L(N,D,EP,NP)=E + \frac{A}{(UN + UN * N^* * (1 - e^{(-1*NP/(N^*))}))^\alpha} + \frac{B}{(U + U * EP^* * (1 - e^{(-1*EP/(EP^*))}))^\beta}$"
params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363]

def scaling_law(N, D, U, params):
    a, b, e, alpha, beta, ep_star, n_star  = params
    A = np.exp(a)
    B = np.exp(b)
    E = np.exp(e)

    ### No Log ###
    EP = np.maximum((D / U) - 1, 0)    
    UN = np.minimum(N,optimal_N(D_to_C(U)))
    NP = np.maximum((N / UN ) - 1, 0)

    ### With Log ###
    #EP = np.log(D / U)
    #UN = np.minimum(N,optimal_N(D_to_C(U)))
    #NP = np.log(N / UN)

    L = E + A/(UN + UN*n_star*(1-np.exp(-1*NP/n_star)))**alpha + B / (U + U * ep_star * (1 - np.exp(-1*EP/(ep_star))))**beta
    return L

"""
# Geom Series
params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 0.038892232, 0.25062278]
#params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 0.028892232, 0.15062278]
#func = r"$L(N,D,EP,NP)=E + \frac{A}{(UN * TODO )^\alpha} + \frac{B}{(U * TODO)^\beta}$"
def scaling_law(N, D, U, params):
    a, b, e, alpha, beta, ep_star, n_star  = params
    A = np.exp(a)
    B = np.exp(b)
    E = np.exp(e)
    UN = np.minimum(N, optimal_N(D_to_C(U)))
    EP = D/U
    NP = N/UN
    L = E + A/(UN * (1-((1-n_star)**NP))/n_star)**alpha + B / (U * (1-((1-ep_star)**EP))/ep_star)**beta
    return L


### Exp decay ###
#params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 0.039664857, 0.28835988]
params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 0.039664857, 0.28835988]
func = r"$L(N,D,EP,NP)=E + \frac{A}{(UN * TODO)^\alpha} + \frac{B}{(U * TODO)^\beta}$"
def scaling_law(N, D, U, params):
    a, b, e, alpha, beta, ep_star, n_star  = params
    A = np.exp(a)
    B = np.exp(b)
    E = np.exp(e)
    UN = np.minimum(N, optimal_N(D_to_C(U)))
    EP = np.maximum((D/U)-1, 0)
    NP = np.maximum((N/UN)-1, 0)
    #L = E + A/(UN * (1-((1-n_star)**NP))/n_star)**alpha + B / (U * (1-((1-ep_star)**EP))/ep_star)**beta
    L = E + A/(UN * (1-np.exp(-1*n_star*NP-n_star))/(1-np.exp(-1*n_star)) )**alpha + B / (U * (1-np.exp(-1*ep_star*EP-ep_star))/(1-np.exp(-1*ep_star)) )**beta
    return L


### Fixed w/ -1 ###

params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 78.102196, 2.8365762]
def scaling_law(N, D, U, params):
    a, b, e, alpha, beta, ep_star, n_star  = params
    A = np.exp(a)
    B = np.exp(b)
    E = np.exp(e)

    EP = np.maximum((D / U) - 1, 0)    
    UN = np.minimum(N,optimal_N(D_to_C(U)))
    NP = np.maximum((N / UN ) - 1, 0)

    L = E + A/(UN + UN*(n_star-1)*(1-np.exp(-1*NP/n_star)))**alpha + B / (U + U * (ep_star-1) * (1 - np.exp(-1*EP/(ep_star))))**beta
    return L
"""
# Out:
# '\n# Geom Series\nparams = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 0.038892232, 0.25062278]\n#params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 0.028892232, 0.15062278]\n#func = r"$L(N,D,EP,NP)=E + \x0crac{A}{(UN * TODO )^\x07lpha} + \x0crac{B}{(U * TODO)^\x08eta}$"\ndef scaling_law(N, D, U, params):\n    a, b, e, alpha, beta, ep_star, n_star  = params\n    A = np.exp(a)\n    B = np.exp(b)\n    E = np.exp(e)\n    UN = np.minimum(N, optimal_N(D_to_C(U)))\n    EP = D/U\n    NP = N/UN\n    L = E + A/(UN * (1-((1-n_star)**NP))/n_star)**alpha + B / (U * (1-((1-ep_star)**EP))/ep_star)**beta\n    return L\n\n\n### Exp decay ###\n#params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 0.039664857, 0.28835988]\nparams = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 0.039664857, 0.28835988]\nfunc = r"$L(N,D,EP,NP)=E + \x0crac{A}{(UN * TODO)^\x07lpha} + \x0crac{B}{(U * TODO)^\x08eta}$"\ndef scaling_law(N, D, U, params):\n    a, b, e, alpha, bet
# ...

# %%
from matplotlib.cm import unregister_cmap
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata

random.seed(42)
np.random.seed(42)

FONTSIZE = 24
FONTSIZE_SMALL = 18 + 2

fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(24, 10), sharey=True)
ax_data = axs[0]
ax_fit = axs[1]


EPOCHS_TO_COLOR = {
    44: "#03071E",
    14: "#6A040F",
    7: "#D00000",
    5: "#DC2F02",
    4: "#E85D04",
    3: "#F48C06",
    2: "#FAA307",
    1: "#FFBA08",
}

TOKS = [
    178e9,
    84e9,
    55e9
]

COLS = [
    "#D00000",
    "#E85D04",
    "#FAA307",
]

PS = [
    PARAMS_MAP["8b7"],
    PARAMS_MAP["4b2"],
    PARAMS_MAP["2b8"],
]

TITLES = [
    "8.7B parameters trained for 178B tokens",
    "4.2B parameters trained for 84B tokens",
    "2.8B parameters trained for 55B tokens",
]

EPOCHS = np.linspace(1, 15, 100)
#RANGE = np.linspace(1e9, 1e14, 10000)
RANGE = np.logspace(np.log10(1e9), np.log10(1e14), 10000)


x_ticks = [1, 2, 4, 7, 10]
x_ticks_str = ["100%", "50%", "25%", "14%", "10%"]
x_ticks_loc = [np.log10(x) for x in x_ticks]
#plt.xticks(x_ticks_loc, x_ticks)
ax_data.set_xticks(x_ticks_loc, x_ticks_str)
ax_data.set_xlim(np.log10(0.9), np.log10(12))
#ax_data.set_ylim(2.28, 2.66)
#ax_data.set_ylim(2.08, 2.35)
#ax_data.set_ylim(2.15, 2.85)
ax_fit.set_ylim(2.15, 2.85)

ax_data.set_xlabel("Fraction of training tokens that are unique", fontsize=FONTSIZE, labelpad=16)
ax_data.set_ylabel("Final test loss", fontsize=FONTSIZE, labelpad=16)

x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10, 100e11, 100e12]
x_ticks_loc = [np.log10(x) for x in x_ticks]
x_ticks_str = ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$", "$10^{13}$", "$10^{14}$"]
x_ticks_str = ["10M", "100M", "1B", "10B", "100B", "1T", "10T", "100T"]

ax_fit.set_xticks(x_ticks_loc, x_ticks_str)
ax_fit.set_xlim(np.log10(10e9), np.log10(1e14))

ax_fit.set_xlabel("Total training tokens", fontsize=FONTSIZE, labelpad=16)

for toks, color, p_base, title in zip(TOKS, COLS, PS, TITLES):
    l_start_f = scaling_law(p_base, toks, toks, params)
    fm = sorted([(t/ut, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == p_base) and (t == toks))])
    l_start_d = fm[0][-1]
    line_us = ax_data.plot(np.log10(EPOCHS), [((scaling_law(p_base, toks, toks/i, params)/l_start_f) * l_start_d) for i in EPOCHS], color=color, linewidth=3.0)
    #line_us = ax_data.plot(np.log10(EPOCHS), [scaling_law(p_base, toks, toks/i, params) for i in EPOCHS], color=color, linewidth=3.0)
    
    l_start = loss_fn(p_base, toks)
    if (title.startswith("4.2B")):
        limit = 2.5
    elif (title.startswith("8.7B")):
        limit = 2.5
    else:
        limit = 3.5

    line_none = ax_data.plot(np.log10([i for i in EPOCHS if i<limit]), [((loss_fn(p_base, toks/i)/l_start) * l_start_d) for i in EPOCHS if i<limit], color='black', linestyle="dashed", dashes=(5, 15), label=r"Loss assuming repeated tokens are worth nothing")
    #line_none = ax_data.plot(np.log10([i for i in EPOCHS if i<limit]), [((loss_fn(p_base, toks/i)/l_start) * l_start_f) for i in EPOCHS if i<limit], color='black', linestyle="dashed", dashes=(5, 15), label=r"Loss assuming repeated tokens are worth nothing")

    dots = ax_data.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], color=color, s=64)
    #dots = ax_data.scatter(np.log10([x[0] for x in fm]), [(x[1]/l_start_d) * l_start_f for x in fm], color=color, s=64)

    cc_line = ax_data.axhline(y=l_start_d, color='black', linestyle="dotted")
    #cc_line = ax_data.axhline(y=l_start_f, color='black', linestyle="dotted")

    ax_data.annotate(
        title,
        xy=(np.log10(fm[0][0]), fm[0][1]-0.04),
        #xy=(np.log10(fm[0][0]), l_start_f-0.03),
        fontweight="bold",
        fontsize=FONTSIZE_SMALL-2,
        color="black",
    )

    ax_fit.plot(np.log10(RANGE), [((scaling_law(p_base, i, min(i, toks), params)/l_start_f) * l_start_d) for i in RANGE], color=color)
    #ax_fit.plot(np.log10(RANGE), [scaling_law(p_base, i, min(i, toks), params) for i in RANGE], color=color)   

    # Only plot after unique toks are hit; No need to emphasize the difference in large N here
    ax_fit.plot(np.log10([i for i in RANGE if i >= toks]), [((loss_fn(p_base, i)/l_start) * l_start_d) for i in RANGE if i >= toks], linestyle="dotted", color=color)
    #ax_fit.plot(np.log10([i for i in RANGE if i >= toks]), [loss_fn(p_base, i) for i in RANGE if i >= toks], linestyle="dotted", color=color)
    
    if (title.startswith("2.8B")):
        ax_fit.plot(np.log10([i for i in RANGE if toks <= i <= toks*20]), [((loss_fn(p_base, toks)/l_start) * l_start_d) for _ in RANGE if toks <= _ <= toks*20], color='black', linestyle="dashed", dashes=(5, 15), label=r"Loss assuming repeated tokens are worth nothing")
        #ax_fit.plot(np.log10([i for i in RANGE if toks <= i <= toks*20]), [loss_fn(p_base, toks) for _ in RANGE if toks <= _ <= toks*20], color='black', linestyle="dashed", dashes=(5, 15), label=r"Loss assuming repeated tokens are worth nothing")

    ax_fit.annotate(
        " ".join(title.split(" ")[:2]),
        xy=(np.log10(10**13.05), ((scaling_law(p_base, RANGE[-20], min(RANGE[-20], toks), params)/l_start_f) * l_start_d)+0.03),
        #xy=(np.log10(10**13.3), scaling_law(p_base, RANGE[-20], min(RANGE[-20], toks), params)+0.01),
        fontweight="bold",
        fontsize=FONTSIZE_SMALL-2,
        color="black",
    )

for toks, color, p_base, title in zip(TOKS, COLS, PS, TITLES):
    lim_s, lim_e = ax_fit.get_ylim()
    #"""
    l_start = loss_fn(p_base, toks)
    l_start_f = scaling_law(p_base, toks, toks, params)
    fm = sorted([(t/ut, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == p_base) and (t == toks))])
    l_start_d = fm[0][-1]
    #"""
    for ep in [1, 2, 4, 8, 16, 32, 64]:
        t = ep * toks
        l = (scaling_law(p_base, t, min(t, toks), params) / l_start_f) * l_start_d
        #l = scaling_law(p_base, t, min(t, toks), params)
        # Based on lim_s & lim_e bring l to a range from 0 to 1
        l_scaled = (l - lim_s) / (lim_e - lim_s)
        plt.axvline(x=np.log10(t), ymin=l_scaled-0.005, ymax=l_scaled+0.005, color='black', linestyle='-')
        if (ep == 1) and (title.startswith("2.8B")):
            plt.annotate(f"{ep} Epoch", xy=(np.log10(t)+0.02, l+0.008), fontsize=FONTSIZE_SMALL-6,)
        else:
            plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.01, l+0.005), fontsize=FONTSIZE_SMALL-6,)


ax_data.set_title(r'Empirical Loss (Fixed training length)', fontsize=FONTSIZE, pad=16)
ax_fit.set_title(r'Predicted Loss (Variable training length)', fontsize=FONTSIZE, pad=16)


ax_fit.tick_params(labelsize=FONTSIZE_SMALL)#, pad=16)
ax_data.tick_params(labelsize=FONTSIZE_SMALL)#, pad=)

#ax_data.grid()
ax_data.spines['right'].set_visible(False)
ax_data.spines['top'].set_visible(False)

ax_fit.spines['right'].set_visible(False)
ax_fit.spines['top'].set_visible(False)


ax_fit.annotate(
    'Repeating for 4 epochs is almost\n            as good as new data', 
    xy=(np.log10(55e9 * 6.5), 2.48), 
    #xy=(np.log10(55e9 * 6), 2.21), 
    xycoords='data',
    xytext=(np.log10(10**12), 2.565), 
    #xytext=(np.log10(10**12), 2.25), 
    textcoords='data',
    va='top', ha='left',
    fontsize=FONTSIZE_SMALL,
    arrowprops=dict(facecolor='black', shrink=0.05, width=2.5)
)

ax_fit.annotate(
    '           ', 
    xy=(np.log10(84e9 * 5.8), 2.4), 
    #xy=(np.log10(55e9 * 6), 2.21), 
    xycoords='data',
    xytext=(np.log10(10**12.15), 2.5), 
    #xytext=(np.log10(10**12), 2.25), 
    textcoords='data',
    va='top', ha='left',
    fontsize=FONTSIZE_SMALL-4,
    arrowprops=dict(facecolor='black', shrink=0.05, width=2.5)
)


ax_fit.annotate(
    '           ', 
    xy=(np.log10(178e9 * 4.8), 2.3), 
    #xy=(np.log10(55e9 * 6), 2.21), 
    xycoords='data',
    xytext=(np.log10(10**12.3), 2.5), 
    #xytext=(np.log10(10**12), 2.25), 
    textcoords='data',
    va='top', ha='left',
    fontsize=FONTSIZE_SMALL-4,
    arrowprops=dict(facecolor='black', shrink=0.05, width=2.5)
)


leg = fig.legend(
    [dots] + [line_none[0]] + [cc_line] + [line_us[0]],
    [
        "Loss of models trained",
        "Loss assuming training is stopped when exhausting all unique data",
        #"Loss assuming repeated data is worth nothing (shortened)",
        "Loss assuming repeated data is worth the same as new data",# (=Chinchilla holds regardless of epochs)"
        "Loss predicted by our data-constrained scaling laws",# + func,         
    ],
    loc='lower center',
    ncol=2,
    frameon=False,
    fontsize=FONTSIZE_SMALL,
    #borderpad=2,
)

#fig.suptitle('Data-constrained Scaling Laws', fontsize=FONTSIZE, fontweight="bold", y=1)
 
leg.legendHandles[0].set_color('black')
leg.legendHandles[-1].set_color('black')

plt.subplots_adjust(wspace=0.1, bottom=0.25)

plt.savefig(f"dualplot.pdf", bbox_inches="tight")
# Out:
# <ipython-input-12-d2169b18a90f>:230: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[0].set_color('black')
# <ipython-input-12-d2169b18a90f>:231: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[-1].set_color('black')

# %% [markdown]
# #### Old Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(500e5, 110e9, 10000)

unique_toks = 100e6

plt.figure(figsize=(16, 12))


#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["14m"]])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"14M model on $10^8$ unique tokens: " + func)
#plt.scatter(np.log10([x[0] for x in fm]), [(x[1]/fm[0][-1])*6 for x in fm], label=r"14M model on $10^8$ unique tokens: " + func)

#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["44m"]])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"44M model on $10^8$ unique tokens: " + func)

#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["83m"]])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"83M model on $10^8$ unique tokens: " + func)

fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["146m"]) and (ut == unique_toks))])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"146M model on $10^8$ unique tokens: " + func)


fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["1b1"]) and (ut == 100e6))])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"1B1 model on 1.5B unique tokens: " + func)


#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["14m"], i, min(i, unique_toks), params) for i in x], label=r"14M model on $10^8$ unique tokens: " + func)
#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["44m"], i, min(i, unique_toks), params) for i in x], label=r"44M model on $10^8$ unique tokens: " + func)
#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["83m"], i, min(i, unique_toks), params) for i in x], label=r"83M model on $10^8$ unique tokens: " + func)
#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["146m"], i, min(i, unique_toks), params) for i in x], label=r"146M model on $10^8$ unique tokens: " + func)

plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["1b1"], i, min(i, 100e6), params) for i in x], label=r"1B1 model on 100M unique tokens: " + func)


#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["14m"], i) for i in x], label=r"14M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["44m"], i) for i in x], label=r"44M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["83m"], i) for i in x], label=r"83M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["146m"], i) for i in x], label=r"146M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")

plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["1b1"], i) for i in x], label=r"1B1 model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")


x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10]
x_ticks_loc = [np.log10(x) for x in x_ticks]
plt.xticks(x_ticks_loc, ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$"])
plt.xlim(np.log10(80e5), np.log10(110e10))

plt.axvline(x=np.log10(unique_toks), color='black', linestyle="--", label='Wall (Tokens are repeated afterwards for Us)')
plt.axvline(x=np.log10(1.5e9), color='black', linestyle="--")#, label='Wall (Tokens are repeated afterwards for Us)')


plt.legend()
plt.title("Expected validation loss")
plt.xlabel("Training Tokens")
plt.ylabel("Validation Loss")
# Out:
# Text(0, 0.5, 'Validation Loss')

# %%
import matplotlib.pyplot as plt
import numpy as np

#x = np.linspace(100e5, 1000e9, 50000)
x = np.linspace(1e9, 1000e9, 50000)

unique_toks = 100e6

plt.figure(figsize=(16, 12))


#plt.scatter(np.log10([x[0] for x in fm]), [(x[1]/fm[0][-1])*6 for x in fm], label=r"14M model on $10^8$ unique tokens: " + func)

#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["44m"]])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"44M model on $10^8$ unique tokens: " + func)



#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["146m"]) and (ut == unique_toks))])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"146M model on $10^8$ unique tokens: " + func)

"""
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["14m"]) and (ut == 100e6)])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"14M model on $10^8$ unique tokens: " + func)
#l_start = scaling_law(PARAMS_MAP["14m"], unique_toks, unique_toks, params)
#plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["14m"], i, min(i, unique_toks), params)/l_start) * fm[0][1] for i in x], label=r"14M model on $10^8$ unique tokens: " + func)

l_end = scaling_law(PARAMS_MAP["14m"], fm[-1][0], unique_toks, params)
plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["14m"], i, min(i, unique_toks), params)/l_end) * fm[-1][1] for i in x], label=r"14M model on $10^8$ unique tokens: " + func)

plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["14m"], i) for i in x], label=r"14M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")

"""

"""
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["83m"]])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"83M model on $10^8$ unique tokens: " + func)
plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["83m"], i, min(i, unique_toks), params) for i in x], label=r"83M model on $10^8$ unique tokens: " + func)
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["83m"], i) for i in x], label=r"83M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
"""

#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["44m"], i, min(i, unique_toks), params) for i in x], label=r"44M model on $10^8$ unique tokens: " + func)
#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["146m"], i, min(i, unique_toks), params) for i in x], label=r"146M model on $10^8$ unique tokens: " + func)



"""
unique_toks = 1.5e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["1b1"]) and (ut == unique_toks)])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"1B1 model on 1.5B unique tokens: " + func, color="red")

l_start = scaling_law(PARAMS_MAP["1b1"], unique_toks, unique_toks, params)

plt.plot(
    np.log10(x), 
    [(scaling_law(PARAMS_MAP["1b1"], i, min(i, unique_toks), params)/l_start) * fm[0][1] for i in x], 
    label=r"1B1 model on 1.5B unique tokens: " + func, 
    color="red",
    #markevery=100,
    #marker='|',
    #markersize=10,
)
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["1b1"], i) for i in x], label=r"1B1 model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
"""



#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["44m"], i) for i in x], label=r"44M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["83m"], i) for i in x], label=r"83M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["146m"], i) for i in x], label=r"146M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")


unique_toks = 12e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (ut == unique_toks))])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"4.2B model on 12B unique tokens: " + func, color="blue")
l_end = scaling_law(PARAMS_MAP["4b2"], 84e9, unique_toks, params)
plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), params)/l_end) * fm[-1][1] for i in x], label=r"4.2B model on 12B unique tokens: " + func, color="blue")
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["4b2"], i) for i in x], label=r"4.2B model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")


unique_toks = 4e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["2b8"]) and (ut == unique_toks))])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"2.8B model on 4B unique tokens: " + func, color="green")

### Normalize via start ###
#l_start = scaling_law(PARAMS_MAP["2b8"], 4e9, 4e9, params)
#plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["2b8"], i, min(i, 4e9), params)/l_start) * fm[0][1] for i in x], label=r"2b8 model on $10^8$ unique tokens: " + func, color="green")

### Normalize via end ###
l_end = scaling_law(PARAMS_MAP["2b8"], 55e9, 4e9, params)
plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["2b8"], i, min(i, 4e9), params)/l_end) * fm[-1][1] for i in x], label=r"2.8B model on 4B unique tokens: " + func, color="green")

### Do not normalize ###
#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["2b8"], i, min(i, 4e9), params) for i in x], label=r"2b8 model on $10^8$ unique tokens: " + func, color="green")

plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["2b8"], i) for i in x], label=r"2.8B model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)", color="red")


lim_s, lim_e = plt.ylim()
for ep in [1, 2, 4, 8, 16]:
    t = ep * 4e9
    #l = (scaling_law(PARAMS_MAP["2b8"], t, min(t, 4e9), params)/l_start) * fm[0][1]
    l = (scaling_law(PARAMS_MAP["2b8"], t, min(t, 4e9), params)/l_end) * fm[-1][1]
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')

    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))


unique_toks = 12e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["4b2"]) and (ut == 12e9)])
#l_start = scaling_law(PARAMS_MAP["14m"], unique_toks, unique_toks, params)
l_end = scaling_law(PARAMS_MAP["4b2"], fm[-1][0], unique_toks, params)
for ep in [1, 2, 4, 8, 16]:
    t = ep * unique_toks
    #l = (scaling_law(PARAMS_MAP["14m"], t, min(t, unique_toks), params)/l_start) * fm[0][1]
    l = (scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), params)/l_end) * fm[-1][1]
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')

    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))


"""
unique_toks = 100e6
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["14m"]) and (ut == 100e6)])
#l_start = scaling_law(PARAMS_MAP["14m"], unique_toks, unique_toks, params)
l_end = scaling_law(PARAMS_MAP["14m"], fm[-1][0], unique_toks, params)

for ep in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]:
    t = ep * unique_toks
    #l = (scaling_law(PARAMS_MAP["14m"], t, min(t, unique_toks), params)/l_start) * fm[0][1]
    l = (scaling_law(PARAMS_MAP["14m"], t, min(t, unique_toks), params)/l_end) * fm[-1][1]
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')

    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))
"""





x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10, 100e11]
x_ticks_loc = [np.log10(x) for x in x_ticks]
plt.xticks(x_ticks_loc, ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$", "$10^{13}$"])
plt.xlim(np.log10(1.5e9), np.log10(110e10))







#plt.axvline(x=np.log10(unique_toks), color='black', linestyle="--", label='Wall (Tokens are repeated afterwards for Us)')
#plt.axvline(x=np.log10(1.5e9), color='black', linestyle="--")#, label='Wall (Tokens are repeated afterwards for Us)')


plt.legend()
plt.title("Expected validation loss")
plt.xlabel("Training Tokens")
plt.ylabel("Validation Loss")

plt.savefig(f"expvalloss_2b4b.pdf", bbox_inches="tight")

# %%
import matplotlib.pyplot as plt
import numpy as np

#x = np.linspace(100e5, 1000e9, 50000)
x = np.linspace(10e6, 1000e9, 50000)

unique_toks = 100e6

plt.figure(figsize=(16, 12))


#plt.scatter(np.log10([x[0] for x in fm]), [(x[1]/fm[0][-1])*6 for x in fm], label=r"14M model on $10^8$ unique tokens: " + func)

#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["44m"]])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"44M model on $10^8$ unique tokens: " + func)



#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["146m"]) and (ut == unique_toks))])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"146M model on $10^8$ unique tokens: " + func)

#"""
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["14m"]) and (ut == 100e6)])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"14M model on $10^8$ unique tokens: " + func)
#l_start = scaling_law(PARAMS_MAP["14m"], unique_toks, unique_toks, params)
#plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["14m"], i, min(i, unique_toks), params)/l_start) * fm[0][1] for i in x], label=r"14M model on $10^8$ unique tokens: " + func)

l_end = scaling_law(PARAMS_MAP["14m"], fm[-1][0], unique_toks, params)
plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["14m"], i, min(i, unique_toks), params)/l_end) * fm[-1][1] for i in x], label=r"14M model on $10^8$ unique tokens: " + func)

plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["14m"], i) for i in x], label=r"14M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")

#"""

"""
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["83m"]])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"83M model on $10^8$ unique tokens: " + func)
plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["83m"], i, min(i, unique_toks), params) for i in x], label=r"83M model on $10^8$ unique tokens: " + func)
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["83m"], i) for i in x], label=r"83M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
"""

#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["44m"], i, min(i, unique_toks), params) for i in x], label=r"44M model on $10^8$ unique tokens: " + func)
#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["146m"], i, min(i, unique_toks), params) for i in x], label=r"146M model on $10^8$ unique tokens: " + func)



"""
unique_toks = 1.5e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["1b1"]) and (ut == unique_toks)])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"1B1 model on 1.5B unique tokens: " + func, color="red")

l_start = scaling_law(PARAMS_MAP["1b1"], unique_toks, unique_toks, params)

plt.plot(
    np.log10(x), 
    [(scaling_law(PARAMS_MAP["1b1"], i, min(i, unique_toks), params)/l_start) * fm[0][1] for i in x], 
    label=r"1B1 model on 1.5B unique tokens: " + func, 
    color="red",
    #markevery=100,
    #marker='|',
    #markersize=10,
)
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["1b1"], i) for i in x], label=r"1B1 model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
"""



#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["44m"], i) for i in x], label=r"44M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["83m"], i) for i in x], label=r"83M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["146m"], i) for i in x], label=r"146M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")



#"""
lim_s, lim_e = plt.ylim()
unique_toks = 100e6
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["14m"]) and (ut == 100e6)])
#l_start = scaling_law(PARAMS_MAP["14m"], unique_toks, unique_toks, params)
l_end = scaling_law(PARAMS_MAP["14m"], fm[-1][0], unique_toks, params)

for ep in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]:
    t = ep * unique_toks
    #l = (scaling_law(PARAMS_MAP["14m"], t, min(t, unique_toks), params)/l_start) * fm[0][1]
    l = (scaling_law(PARAMS_MAP["14m"], t, min(t, unique_toks), params)/l_end) * fm[-1][1]
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')

    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))
#"""





x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10, 100e11]
x_ticks_loc = [np.log10(x) for x in x_ticks]
plt.xticks(x_ticks_loc, ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$", "$10^{13}$"])
plt.xlim(np.log10(90e6), np.log10(110e9))







#plt.axvline(x=np.log10(unique_toks), color='black', linestyle="--", label='Wall (Tokens are repeated afterwards for Us)')
#plt.axvline(x=np.log10(1.5e9), color='black', linestyle="--")#, label='Wall (Tokens are repeated afterwards for Us)')


plt.legend()
plt.title("Expected validation loss")
plt.xlabel("Training Tokens")
plt.ylabel("Validation Loss")
plt.savefig(f"expvalloss_14m.pdf", bbox_inches="tight")

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(100e5, 110e9, 10000)
x = np.linspace(1, 15, 100)
plt.figure(figsize=(16, 12))

FONTSIZE=20


toks = 178e9

l_start = scaling_law(PARAMS_MAP["8b7"], toks, toks, params)

fm = sorted([(t/ut, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["8b7"]) and (t == 178e9))])
l_start_d = fm[0][-1]

plt.plot(np.log10(x), [((scaling_law(PARAMS_MAP["8b7"], toks, toks/i, params)/l_start) * l_start_d) for i in x], label=r"8.7B parameters on 178B tokens: Our scaling law")

plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"8.7B parameters on 178B tokens: Empirical")

plt.axhline(y=l_start_d, color='black', linestyle="--")



toks = 84e9

l_start = scaling_law(PARAMS_MAP["4b2"], toks, toks, params)

fm = sorted([(t/ut, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (t == 84e9) and (t/ut < 10))])
l_start_d = fm[0][-1]

plt.plot(np.log10(x), [((scaling_law(PARAMS_MAP["4b2"], toks, toks/i, params)/l_start) * l_start_d) for i in x], label=r"4.2B parameters on 84B tokens: Our scaling law")

plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"4.2B parameters on 84B tokens: Empirical")

plt.axhline(y=l_start_d, color='black', linestyle="--")#, label='Assuming repeated is worth the same as new data (=Chinchilla holds for multiple epochs)')

#"""
toks = 55e9
l_start = scaling_law(PARAMS_MAP["2b8"], toks, toks, params)
fm = sorted([(t/ut, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["2b8"]) and (t == 55e9) and (t/ut < 10))])
l_start_d = fm[0][-1]

plt.plot(np.log10(x), [((scaling_law(PARAMS_MAP["2b8"], toks, toks/i, params)/l_start) * l_start_d) for i in x], label=r"2.8B parameters on 55B tokens: Our scaling law")

plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"2.8B parameters on 55B tokens: Empirical" )

plt.axhline(y=l_start_d, color='black', linestyle="--", label='Assuming repeated is worth the same as new data (=Chinchilla holds for multiple epochs)')
#, label='Assuming Chinchilla holds for multiple epochs')

#"""


#x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10]
x_ticks = [1, 2, 4, 6, 10]
x_ticks_loc = [np.log10(x) for x in x_ticks]
plt.xticks(x_ticks_loc, x_ticks)
plt.xlim(np.log10(0.9), np.log10(14))

plt.ylim(2.2, 2.9)


plt.grid()

plt.legend(
    fontsize=12
)

plt.title("Effect on loss from training on repeated data", fontsize=FONTSIZE)
plt.xlabel("Epochs", fontsize=FONTSIZE)
plt.ylabel("Validation Loss", fontsize=FONTSIZE)
# Out:
# Text(0, 0.5, 'Validation Loss')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(100e5, 110e9, 10000)
x = np.linspace(1, 15, 100)
plt.figure(figsize=(16, 12))

FONTSIZE=20
FONTSIZE_SMALL=12



EPOCHS_TO_COLOR = {
    44: "#03071E",
    14: "#6A040F",
    7: "#D00000",
    5: "#DC2F02",
    4: "#E85D04",
    3: "#F48C06",
    2: "#FAA307",
    1: "#FFBA08",
}


toks = 178e9
color = EPOCHS_TO_COLOR[7]

l_start = scaling_law(PARAMS_MAP["8b7"], toks, toks, params)

fm = sorted([(t/ut, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["8b7"]) and (t == 178e9))])
l_start_d = fm[0][-1]

plt.plot(np.log10(x), [((scaling_law(PARAMS_MAP["8b7"], toks, toks/i, params)/l_start) * l_start_d) for i in x], color=color, linewidth=3.0)

l_start = loss_fn(PARAMS_MAP["8b7"], toks)
line_none = plt.plot(np.log10([i for i in x if i<3.5]), [((loss_fn(PARAMS_MAP["8b7"], toks/i)/l_start) * l_start_d) for i in x if i <3.5], color='black', linestyle="dashed", dashes=(5, 25), label=r"Loss assuming repeated tokens are worth nothing")

plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], color=color, s=64)

plt.axhline(y=l_start_d, color='black', linestyle="dotted")


plt.annotate(
    "8.7B parameters trained for 178B tokens", 
    #xy=(np.log10(fm[0][0])+0.05, fm[0][1]+0.025),
    xy=(np.log10(fm[0][0]), fm[0][1]-0.025),
    fontweight="bold", 
    fontsize=FONTSIZE_SMALL,
    color="black",
)



toks = 84e9
color = EPOCHS_TO_COLOR[4]

l_start = scaling_law(PARAMS_MAP["4b2"], toks, toks, params)

fm = sorted([(t/ut, l, n) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (t == 84e9) and (t/ut < 10))])

all_scores = []
all_std = []
for ep, l, n in fm:
    seed_scores = [l]
    for n_seed, l_seed in NAMES_TO_VAL_LOSSES.items():
      if (n in n_seed) and ("seed" in n_seed):
          seed_scores.append(l_seed)
    all_scores.append(np.mean(seed_scores))
    all_std.append(np.std(seed_scores))

#l_start_d = fm[0][-1]
l_start_d = all_scores[0]
print(all_std)

plt.plot(np.log10(x), [((scaling_law(PARAMS_MAP["4b2"], toks, toks/i, params)/l_start) * l_start_d) for i in x], label=r"4.2B parameters on 84B tokens: Our scaling law", color=color, linewidth=3.0)


l_start = loss_fn(PARAMS_MAP["4b2"], toks)
line_none = plt.plot(np.log10([i for i in x if i<3]), [((loss_fn(PARAMS_MAP["4b2"], toks/i)/l_start) * l_start_d) for i in x if i <3], color='black', linestyle="dashed", dashes=(5, 25), label=r"Loss assuming repeated tokens are worth nothing")


#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"4.2B parameters on 84B tokens: Empirical")
plt.scatter(np.log10([x[0] for x in fm]), all_scores, color=color, s=64)


plt.axhline(y=l_start_d, color='black', linestyle="dotted")#, label='Assuming repeated is worth the same as new data (=Chinchilla holds for multiple epochs)')


plt.annotate(
    "4.2B parameters trained for 84B tokens", 
    #xy=(np.log10(fm[0][0])+0.05, fm[0][1]+0.025), 
    xy=(np.log10(fm[0][0]), fm[0][1]-0.025),
    fontweight="bold", 
    fontsize=FONTSIZE_SMALL,
    color="black",
)


#"""
toks = 55e9
color = EPOCHS_TO_COLOR[2]

l_start = scaling_law(PARAMS_MAP["2b8"], toks, toks, params)
fm = sorted([(t/ut, l, n) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["2b8"]) and (t == 55e9) and (t/ut < 10))])

all_scores = []
all_std = []
for ep, l, n in fm:
    seed_scores = [l]
    for n_seed, l_seed in NAMES_TO_VAL_LOSSES.items():
      if (n in n_seed) and ("seed" in n_seed):
          seed_scores.append(l_seed)
    all_scores.append(np.mean(seed_scores))
    all_std.append(np.std(seed_scores))

# l_start_d = fm[0][1]
l_start_d = all_scores[0]

line_us = plt.plot(np.log10(x), [((scaling_law(PARAMS_MAP["2b8"], toks, toks/i, params)/l_start) * l_start_d) for i in x], label=r"2.8B parameters on 55B tokens: Our scaling law", color=color, linewidth=3.0)

l_start = loss_fn(PARAMS_MAP["2b8"], toks)
line_none = plt.plot(np.log10([i for i in x if i<3.2]), [((loss_fn(PARAMS_MAP["2b8"], toks/i)/l_start) * l_start_d) for i in x if i <3.2], color='black', linestyle="dashed", dashes=(5, 25), label=r"Loss assuming repeated tokens are worth nothing")


# Does not make sense as std is not visible
# dots = plt.errorbar(np.log10([x[0] for x in fm]), all_scores, yerr=all_std, fmt='o')
dots = plt.scatter(np.log10([x[0] for x in fm]), all_scores, label=r"2.8B parameters on 55B tokens: Empirical", color=color, s=64)


#dots = plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"2.8B parameters on 55B tokens: Empirical" )

cc_line = plt.axhline(y=l_start_d, color='black', linestyle="dotted", label='Assuming repeated is worth the same as new data (=Chinchilla holds for multiple epochs)')



#, label='Assuming Chinchilla holds for multiple epochs')

#"""

plt.annotate(
    "2.8B parameters trained for 55B tokens", 
    #xy=(np.log10(fm[0][0])+0.05, fm[0][1]+0.025), 
    xy=(np.log10(fm[0][0]), fm[0][1]-0.025),
    fontweight="bold", 
    fontsize=FONTSIZE_SMALL,
    color="black",
)



#x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10]
x_ticks = [1, 2, 4, 7, 10]
x_ticks_str = ["100%", "50%", "25%", "14%", "10%"]
x_ticks_loc = [np.log10(x) for x in x_ticks]
#plt.xticks(x_ticks_loc, x_ticks)
plt.xticks(x_ticks_loc, x_ticks_str)
plt.xlim(np.log10(0.9), np.log10(12))

plt.ylim(2.25, 2.7)


plt.grid()

leg = plt.legend(
    [dots] + [line_none[0]] + [cc_line] + [line_us[0]],
    [
        "Loss of models trained",
        "Loss assuming repeated data is worth nothing (Shortened)",
        "Loss assuming repeated data is worth the same as new data",# (=Chinchilla holds regardless of epochs)"
        "Loss predicted by our Decaying Scaling Laws",# + func,         
    ],
    #[x for x in bar], 
    #[str(x) for x in epoch_to_models], 
    #title="Epochs", 
    fontsize=12,
    frameon=True,
    #ncol=1,
    #title_fontproperties={'weight': 'bold', "size": FONTSIZE},
    #columnspacing=0.9,
    #loc=(-0.3, 0.9), #"upper center"
    loc="upper left",
)

leg.legendHandles[0].set_color('black')
leg.legendHandles[-1].set_color('black')

plt.title("Performance impact of training for multiple epochs", fontsize=FONTSIZE, pad=16, fontweight="bold")
plt.xlabel("Fraction of training tokens that are unique", fontsize=FONTSIZE)
plt.ylabel("Final test loss", fontsize=FONTSIZE)
plt.savefig(f"perfimpact.pdf", bbox_inches="tight")
# Out:
# [0.009215945472928987, 0.008553937502694328, 0.00889073564110417, 0.011157659396127872, 0.02225193770798413, 0.005325246908829725]
# <ipython-input-74-7dd4dc000d44>:184: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[0].set_color('black')
# <ipython-input-74-7dd4dc000d44>:185: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   leg.legendHandles[-1].set_color('black')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(9e9, 1e14, 10000)

plt.figure(figsize=(16, 12))

plt.ylim((2.0, 2.35))
lim_s, lim_e = plt.ylim()

unique_toks = 55e9
model_s = "2b8"
plt.plot(np.log10(x), [scaling_law(PARAMS_MAP[model_s], i, min(i, unique_toks), params) for i in x], label=r"2.8B model on 55B unique tokens")
for ep in [1, 2, 4, 8, 16, 32, 64]:
    t = ep * unique_toks
    l = scaling_law(PARAMS_MAP[model_s], t, min(t, unique_toks), params)
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.01, l+0.005))


unique_toks = 84e9
model_s = "4b2"
plt.plot(np.log10(x), [scaling_law(PARAMS_MAP[model_s], i, min(i, unique_toks), params) for i in x], label=r"4.2B model on 84B unique tokens")
for ep in [1, 2, 4, 8, 16, 32, 64]:
    t = ep * unique_toks
    l = scaling_law(PARAMS_MAP[model_s], t, min(t, unique_toks), params)
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.01, l+0.005))

unique_toks = 178e9
model_s = "8b7"
plt.plot(np.log10(x), [scaling_law(PARAMS_MAP[model_s], i, min(i, unique_toks), params) for i in x], label=r"8.7B model on 178B unique tokens")
for ep in [1, 2, 4, 8, 16, 32, 64]:
    t = ep * unique_toks
    l = scaling_law(PARAMS_MAP[model_s], t, min(t, unique_toks), params)
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.01, l+0.005))




plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["2b8"], i) for i in x], label=r"2.8B model on all unique tokens", linestyle="dotted")
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["4b2"], i) for i in x], label=r"4.2B model on all unique tokens", linestyle="dotted")
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["8b7"], i) for i in x], label=r"8.7B model on all unique tokens", linestyle="dotted")
#plt.plot(np.log10(x), [scaling_law(100e9, i, params) for i in x], label=r"100B model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")

x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10, 100e11, 100e12]
x_ticks_loc = [np.log10(x) for x in x_ticks]
plt.xticks(x_ticks_loc, ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$", "$10^{13}$", "$10^{14}$"])
plt.xlim(np.log10(10e9), np.log10(1e14))

#plt.axvline(x=np.log10(unique_toks), color='black', linestyle="--", label='Wall (Tokens are repeated afterwards for Us)')



plt.legend()
plt.title("Final Test Loss")
plt.xlabel("Total Training Tokens")
plt.ylabel("Validation Loss")
plt.savefig(f"scalingpred.pdf", bbox_inches="tight")

# %%
from matplotlib.cm import unregister_cmap
import random
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata


random.seed(42)
np.random.seed(42)

FONTSIZE = 24
FONTSIZE_SMALL = 16


fig, ax = plt.subplots(figsize=(12, 12))

UT = 12e9
P = optimal_N(D_to_C(UT))

base_model = "4b284b12b"
base_l = NAMES_TO_VAL_LOSSES[base_model]
base_p = PARAMS_MAP["4b2"] / P
base_e = (41_015_625 * 2048) / UT
print(6 * PARAMS_MAP["4b2"] * 41_015_625 * 2048)

#opt_model = "4b284b12bopt"
opt_model = "4b284b12bc4opt4"#"4b284b12bopt4"
best_l = NAMES_TO_VAL_LOSSES[opt_model]
best_p = 3.089856e9 / P#3.1e9 / P#PARAMS_MAP["3b8"] / P
best_e = (56_152_344 * 2048 / UT)#(48_828_125 * 2048) / UT
print(6 * 3.089856e9 * 56_152_344 * 2048)





"""
UT = 4e9
P = optimal_N(D_to_C(UT))

base_model = "2b855b4b"
base_l = NAMES_TO_VAL_LOSSES[base_model]
base_p = PARAMS_MAP["2b8"] / P
base_e = (26_855_469 * 2048) / UT

opt_model = "2b855b4bc4opt2"
best_l = NAMES_TO_VAL_LOSSES[opt_model]
best_p = PARAMS_MAP["2b2"] / P # Should be ~1.8e9
best_e = ((36_279_297) * 2048) / UT
"""

#x_ticks = [1, 4, 30, 100] + [round(base_e, 1), round(best_e, 1)]
#x_ticks_loc = [np.log10(x) for x in x_ticks]

x_ticks = [1, 4, 30, 100] + [round(base_e, 1), round(best_e, 1)]
x_ticks_loc = [np.log10(x) for x in x_ticks]
x_ticks = [f"{round(x*12)}B\n({x})" for x in x_ticks]

ax.set_xticks(x_ticks_loc, x_ticks)
ax.set_xlim(np.log10(0.9), np.log10(40))

y_ticks = [1, 4, 10, 30, 100] + [base_p, best_p]
#y_ticks_str = [str(round(x*P))[:-6] + "M" for x in y_ticks]
#y_ticks_str = [str(round(x*P))[:-9] + "B" for x in y_ticks]
#y_ticks_str = [str(round(x*P))[:-9] + "B" if x != 1 else "0.6B" for x in y_ticks]
y_ticks_str = ["0.59B", "2.4B", "5.9B", "18B", "59B", "4.2B", "3.1B"]

y_ticks_loc = [np.log10(x) for x in y_ticks]
ax.set_yticks(y_ticks_loc, y_ticks_str)
ax.set_ylim(np.log10(0.9), np.log10(40))

ax.tick_params(labelsize=FONTSIZE_SMALL)


MIN_PARAMS, MAX_PARAMS = 100e6, 1e12
MIN_TOKS, MAX_TOKS = 100e6, 1e12

f_min = MIN_PARAMS * MIN_TOKS * 6
f_max = MAX_PARAMS * MAX_TOKS * 6

c_c4 = np.logspace(np.log10(f_min), np.log10(f_max), 1000)
toks_c4 = np.log10(np.array([optimal_D(x)/UT for x in c_c4]))
size_c4 = np.log10(np.array([optimal_N(x)/P for x in c_c4]))

ax.plot(toks_c4, size_c4, label=r"Chinchilla scaling laws efficient frontier", color="black", linestyle="--", linewidth=4.0)

ax.scatter([np.log10(base_e)], [np.log10(base_p)], s=900, marker='*', edgecolor="black", zorder=10)
ax.annotate(f"Loss: {round(base_l, 3)}", (np.log10(base_e) - 0.12, np.log10(base_p) + 0.05), fontsize=FONTSIZE_SMALL, weight='bold')


ax.scatter([np.log10(best_e)], [np.log10(best_p)], s=900, marker='*', color="red", edgecolor="black", zorder=10)
ax.annotate(f"Loss: {round(best_l, 3)}", (np.log10(best_e) + 0.02, np.log10(best_p) - 0.05), fontsize=FONTSIZE_SMALL, weight='bold')

ax.vlines(x=np.log10(base_e), ymin=-10, ymax=np.log10(base_p), color='lightgrey', zorder=-1, linestyle='-')
ax.hlines(y=np.log10(base_p), xmin=-10, xmax=np.log10(base_e), color='lightgrey', zorder=-1, linestyle='-')

ax.vlines(x=np.log10(best_e), ymin=-10, ymax=np.log10(best_p), color='lightgrey', zorder=-1, linestyle='-')
ax.hlines(y=np.log10(best_p), xmin=-10, xmax=np.log10(best_e), color='lightgrey', zorder=-1, linestyle='-')


# Gridsearch for optimal values
#"""
toks_opt = []
size_opt = []
loss_opt = []

last_l = float("inf")
toks_c4 = np.array([optimal_D(x) for x in c_c4])
size_c4 = np.array([optimal_N(x) for x in c_c4])

start_t, end_t = ax.get_xlim()
start_s, end_s = ax.get_ylim()

for t, s in zip(toks_c4, size_c4):

    if not(start_t <= np.log10(t/UT) <= end_t) or not(start_s <= np.log10(s/P) <= end_s):
        continue

    min_l, min_t, min_s = scaling_law(s, t, min(UT, t), params), t, s
      
    for i in np.linspace(1.01, 3, 500):
        D =  t*i
        U = min(UT, D)
        N = s/i

        new_l = scaling_law(N, D, U, params)
        if new_l < min_l:
            min_l, min_t, min_s = new_l, D, N

        D =  t/i
        U = min(UT, D)
        N = s*i
        
        new_l = scaling_law(N, D, U, params)
        if new_l < min_l:
            min_l, min_t, min_s = new_l, D, N
    
    if min_l >= last_l:
        print("Loss is not improving")
        break
    
    toks_opt.append(min_t / UT)
    size_opt.append(min_s / P)
    loss_opt.append(min_l)    

    last_l = min_l

ax.scatter(
    np.log10(toks_opt),
    np.log10(size_opt),
    s=128, 
    #color='black', 
    #label="Data-constrained Scaling Laws",
    c=loss_opt,
    cmap="gist_heat_r",
    zorder=2,
    #edgecolor="black",
    #linewidth=0.2,
)

ax.plot(
    [],#np.log10([t for t,l in zip(toks_opt, loss_opt) if not(Z.min() <= l <= Z.min() + 1)]),
    [],#np.log10([s for s,l in zip(size_opt, loss_opt) if not(Z.min() <= l <= Z.min() + 1)]),
    #s=128, 
    color='black', 
    label="Data-constrained scaling laws efficient frontier",
    #c=[l for l in loss_opt if not(Z.min() <= l <= Z.min() + 1)],
    #cmap=outer_cmap,#contours.cmap,
    #zorder=2,
    #edgecolor="black",
    linewidth=8,
)

handles, labels = ax.get_legend_handles_labels()
for h, l in zip(handles, labels):
    if l == "Data-constrained scaling laws efficient frontier":
        to_map = h


from matplotlib.legend_handler import HandlerLineCollection
from matplotlib.collections import LineCollection
# Make handles with gradient as well, but black seems fine
# https://stackoverflow.com/questions/49223702/adding-a-legend-to-a-matplotlib-plot-with-a-multicolored-line
class HandlerColorLineCollection(HandlerLineCollection):
    def create_artists(self, legend, artist ,xdescent, ydescent,
                        width, height, fontsize,trans):
        x = np.linspace(0,width,self.get_numpoints(legend)+1)
        y = np.zeros(self.get_numpoints(legend)+1)+height/2.-ydescent
        points = np.array([x, y]).T.reshape(-1, 1, 2)
        segments = np.concatenate([points[:-1], points[1:]], axis=1)
        lc = LineCollection(segments, cmap='gist_heat',
                     transform=trans)
        lc.set_array(x)
        lc.set_linewidth(artist.get_linewidth())
        return [lc]


legend = plt.legend(
    #handles, 
    #labels, 
    loc='upper center', 
    ncol=3, 
    frameon=False, 
    fontsize=FONTSIZE_SMALL,
    handler_map={to_map: HandlerColorLineCollection(numpoints=4)},
)


"""
plt.plot(
    np.log10(toks_opt), 
    np.log10(size_opt), 
    label="Multi-Epoch Scaling Laws", 
    color="#023047", 
    linestyle="-", 
    linewidth=8.0,
    #marker=".",
    markersize=8,
)
"""

import matplotlib as mpl

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

"""
ax.plot(
    np.log10([base_p, best_p]),
    np.log10([base_e, best_e]),
    linewidth=4.0,
    label="IsoFLOP"
)
"""

#plt.xlabel('Epochs', fontsize=FONTSIZE)
ax.set_xlabel('Billion tokens\n(Epochs)', fontsize=FONTSIZE, labelpad=16)
ax.set_ylabel("Billion parameters", fontsize=FONTSIZE, labelpad=16)
# Out:
# 2.140236e+21
# 2.1320006494920376e+21
# Text(0, 0.5, 'Billion parameters')

# %%
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (ut == unique_toks))])
fm
# Out:
# [(12000000000.0, 2.84889),
#  (24000000000.0, 2.691483),
#  (36000000000.0, 2.618343),
#  (48000000000.0, 2.577519),
#  (60000000000.0, 2.56039),
#  (72000000000.0, 2.539524),
#  (84000000000.0, 2.526961)]

# %%
new_start_point = 2.848890E+00 # "4b212b12b"
new_end_point = 2.456530E+00 # "4b284b84b"

start_point = loss_fn(PARAMS_MAP["4b2"], 12e9)
end_point = loss_fn(PARAMS_MAP["4b2"], 84e9)


# https://stackoverflow.com/questions/929103/convert-a-number-range-to-another-range-maintaining-ratio
#OldRange = (OldMax - OldMin)  
#NewRange = (NewMax - NewMin)  
#NewValue = (((OldValue - OldMin) * NewRange) / OldRange) + NewMin
old_range = start_point - end_point
new_range = new_start_point - new_end_point

new_cc_values = [
    (((loss_fn(PARAMS_MAP["4b2"], i[0]) - end_point) * new_range) / old_range) + new_end_point for i in fm
]
x = np.linspace(1e9, 100e12, 10000)
x = np.logspace(np.log10(1e9), np.log10(100e12), 10000)

new_cc_curve = [
    (((loss_fn(PARAMS_MAP["4b2"], i) - end_point) * new_range) / old_range) + new_end_point for i in x
]
print(new_cc_values)
# Out:
# [2.84889, 2.676435756668513, 2.5940137083454133, 2.5425007630369234, 2.5061045147289494, 2.4784884412523116, 2.45653]

# %%
new_start_point = 2.848890 # "4b212b12b"
new_end_point = 2.526961 # "4b284b12b"

start_point = scaling_law(PARAMS_MAP["4b2"], 12e9, 12e9, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])
end_point = scaling_law(PARAMS_MAP["4b2"], 84e9, 12e9, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])

# https://stackoverflow.com/questions/929103/convert-a-number-range-to-another-range-maintaining-ratio
#OldRange = (OldMax - OldMin)  
#NewRange = (NewMax - NewMin)  
#NewValue = (((OldValue - OldMin) * NewRange) / OldRange) + NewMin
old_range = start_point - end_point
new_range = new_start_point - new_end_point
    
new_dc_values = [
    (((scaling_law(PARAMS_MAP["4b2"], i[0], min(i[0], 12e9), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363]) - end_point) * new_range) / old_range) + new_end_point for i in fm
]
x = np.linspace(1e9, 100e12, 10000)
x = np.logspace(np.log10(1e9), np.log10(100e12), 10000)

new_dc_curve = [
    (((scaling_law(PARAMS_MAP["4b2"], i, min(i, 12e9), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363]) - end_point) * new_range) / old_range) + new_end_point for i in x    
]

print(new_dc_values)
# Out:
# [2.84889, 2.7020648284193842, 2.634246889663667, 2.5929526363817104, 2.5644703068412897, 2.5433597908669814, 2.526961]

# %%
fig, ax = plt.subplots(figsize=(8, 8))

x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10, 100e11, 100e12]
#x_ticks_loc = [np.log10(x) for x in x_ticks]
x_ticks_str = ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$", "$10^{13}$", "$10^{14}$"]
x_ticks_str = ["10M", "100M", "1B", "10B", "100B", "1T", "10T", "100T"]

x_ticks = [np.log10(x) for x in x_ticks]

ax.set_xticks(x_ticks, x_ticks_str)
#ax.set_xlim(np.log10(10e9), np.log10(1e12))

ax.set_xlim(np.log10(1e9), np.log10(100e12))
ax.set_ylim(2.0, 5.0)

#ax.set_xlim(1e9, 400e9)

ax.set_xlabel("Total training tokens", fontsize=FONTSIZE, labelpad=16)

#ax.set_ylim(2.0, 2.5)
ax.set_ylabel("Final test loss", fontsize=FONTSIZE, labelpad=16)


fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (ut == unique_toks))])


ax.scatter(
    np.log10([x[0] for x in fm]),
    #[x[0] for x in fm],
    [x[1] for x in fm], 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="blue"
)
"""
ax.scatter(
    [x[0] for x in fm],
    new_dc_values, 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="green"
)
"""

ax.plot(
    np.log10(x),
    #x,
    new_dc_curve, 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="green"
)

#x = np.linspace(1e9, 100e9, 1000)

#offset = new_dc_values

#ax.plot(
#    x,
#    [scaling_law(PARAMS_MAP["4b2"], i, min(i, 12e9), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])*1.11 for i in x],
#    color="green"
#)

"""
ax.scatter(
    [x[0] for x in fm],
    new_cc_values, 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="red"
)
"""

ax.plot(
    np.log10(x),
    #x,
    new_cc_curve, 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="red"
)


lim_s, lim_e = ax.get_ylim()
l_end = scaling_law(PARAMS_MAP["4b2"], fm[-1][0], unique_toks, params)
for ep in [1, 2, 4, 8, 16]:
    t = ep * unique_toks
    #l = (scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), params)/l_start) * fm[0][1]
    #l = (scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), params)/l_end) * fm[-1][1]
    #l = scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])

    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l = (((scaling_law(PARAMS_MAP["4b2"], t, min(t, 12e9), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363]) - end_point) * new_range) / old_range) + new_end_point
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    
    ax.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #ax.axvline(x=t, ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    ax.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))
    #ax.annotate(f"{ep} Ep.", xy=(t+0.05, l+0.02))

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10, 100e11, 100e12]
#x_ticks_loc = [np.log10(x) for x in x_ticks]
x_ticks_str = ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$", "$10^{13}$", "$10^{14}$"]
x_ticks_str = ["10M", "100M", "1B", "10B", "100B", "1T", "10T", "100T"]

#x_ticks = [np.log10(x) for x in x_ticks]

ax.set_xticks(x_ticks, x_ticks_str)
#ax.set_xlim(np.log10(10e9), np.log10(2e12))
#ax.set_ylim(2.2, 2.95)

ax.set_xlim(1.5e9, 200e9)

ax.set_xlabel("Total training tokens", fontsize=FONTSIZE, labelpad=16)

#ax.set_ylim(2.0, 2.5)
ax.set_ylabel("Final test loss", fontsize=FONTSIZE, labelpad=16)


fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (ut == unique_toks))])


ax.scatter(
    #np.log10([x[0] for x in fm]),
    [x[0] for x in fm],
    [x[1] for x in fm], 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="blue"
)
"""
ax.scatter(
    [x[0] for x in fm],
    new_dc_values, 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="green"
)
"""

ax.plot(
    #np.log10(x),
    x,
    new_dc_curve, 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="green"
)

#x = np.linspace(1e9, 100e9, 1000)

#offset = new_dc_values

#ax.plot(
#    x,
#    [scaling_law(PARAMS_MAP["4b2"], i, min(i, 12e9), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])*1.11 for i in x],
#    color="green"
#)

"""
ax.scatter(
    [x[0] for x in fm],
    new_cc_values, 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="red"
)
"""

ax.plot(
    #np.log10(x),
    x,
    new_cc_curve, 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="red"
)


lim_s, lim_e = ax.get_ylim()
l_end = scaling_law(PARAMS_MAP["4b2"], fm[-1][0], unique_toks, params)
for ep in [1, 2, 4, 8, 16]:
    t = ep * unique_toks
    #l = (scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), params)/l_start) * fm[0][1]
    #l = (scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), params)/l_end) * fm[-1][1]
    #l = scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])

    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l = (((scaling_law(PARAMS_MAP["4b2"], t, min(t, 12e9), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363]) - end_point) * new_range) / old_range) + new_end_point
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    
    #ax.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    ax.axvline(x=t, ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #ax.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))
    ax.annotate(f"{ep} Ep.", xy=(t+0.05, l+0.02))

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
l = scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])

# Based on lim_s & lim_e bring l to a range from 0 to 1
l_scaled = (l - lim_s) / (lim_e - lim_s)

# %%
ratio = 2.456530E+00 / loss_fn(PARAMS_MAP["4b2"], 84e9) 
[loss_fn(PARAMS_MAP["4b2"], i[0])*ratio for i in fm]
# Out:
# [2.6892825597119643,
#  2.586980677337121,
#  2.538086950341748,
#  2.507528866238237,
#  2.485938184319608,
#  2.469556005221634,
#  2.45653]

# %%
ratio
# Out:
# 1.1019467133314

# %%
"4b284b84b": 2.456530E+00,

# %%
2.84889/2.526961
# Out:
# 1.12739769232687

# %%
[loss_fn(PARAMS_MAP["4b2"], i[0]) for i in fm]
# Out:
# [2.4404833075655157,
#  2.3476458943429064,
#  2.3032755755209027,
#  2.275544575705923,
#  2.2559513579419206,
#  2.2410847778253125,
#  2.229263874814264]

# %%
2.4404833075655157/2.229263874814264
# Out:
# 1.0947485109939485

# %%
fig, ax = plt.subplots(figsize=(4,4))

fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (ut == unique_toks))])
fm_start = fm[0][1]

cc = [loss_fn(PARAMS_MAP["4b2"], i[0]) for i in fm]

ax.scatter(
    np.log10([x[0] for x in fm]),
    [(x[1]/fm_start) for x in fm], 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="blue"
)

ax.scatter(
    np.log10([x[0] for x in fm]),
    [(c/cc[0]) for c in cc], 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="red"
)

# %%
import matplotlib.pyplot as plt
import numpy as np

#x = np.linspace(100e5, 1000e9, 50000)
x = np.linspace(10e9, 1e13, 50000)

unique_toks = 100e6

fig, ax = plt.subplots(figsize=(16, 16))

x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10, 100e11, 100e12]
x_ticks_loc = [np.log10(x) for x in x_ticks]
x_ticks_str = ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$", "$10^{13}$", "$10^{14}$"]
x_ticks_str = ["10M", "100M", "1B", "10B", "100B", "1T", "10T", "100T"]

ax.set_xticks(x_ticks_loc, x_ticks_str)
ax.set_xlim(np.log10(10e9), np.log10(1e12))
ax.set_xlabel("Total training tokens", fontsize=FONTSIZE, labelpad=16)

ax.set_ylim(2.0, 2.5)
ax.set_ylabel("Final test loss", fontsize=FONTSIZE, labelpad=16)

unique_toks = 12e9

fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (ut == unique_toks))])
fm = fm[1:]

fm_start = fm[0][1]
fm_end = fm[-1][1]
fm_avg = [x[-1] for x in fm]
fm_avg = sum(fm_avg) / len(fm_avg)

l_start = scaling_law(PARAMS_MAP["4b2"], 12e9, unique_toks, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])
l_start = scaling_law(PARAMS_MAP["4b2"], 24e9, unique_toks, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])
#l_start = scaling_law(PARAMS_MAP["4b2"], 24e9, unique_toks, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 9999999])
l_end = scaling_law(PARAMS_MAP["4b2"], 84e9, unique_toks, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])

ax.scatter(
    np.log10([x[0] for x in fm]),
    [(x[1]/fm_avg)*l_start for x in fm], 
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="blue"
)



ax.plot(
    np.log10(x), 
#    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])/l_start) * fm[0][1] for i in x],
#    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])/l_end) * fm[-1][1] for i in x],
    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])) for i in x],
#    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 9999999])/l_start) for i in x],
#    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 9999999])) for i in x],
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="blue"
)

#ax.plot(np.log10(x), [loss_fn(PARAMS_MAP["4b2"], i) for i in x], label=r"4.2B model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")

#params = [6.007338, 6.016157, 0.52472854, 0.34, 0.28, 508.22855, 287.73526]#323.87842, 236.72693]
#params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363]

l_start = scaling_law(PARAMS_MAP["4b2"], 12e9, unique_toks, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 9999999, 4.9642363])
l_start = scaling_law(PARAMS_MAP["4b2"], 24e9, unique_toks, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 9999999, 4.9642363])
#l_start = scaling_law(PARAMS_MAP["4b2"], 24e9, unique_toks, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 9999999, 9999999])
l_end = scaling_law(PARAMS_MAP["4b2"], 84e9, unique_toks, [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 9999999, 4.9642363])


ax.plot(
    np.log10(x), 
#    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 999999, 4.9642363])/l_start) * fm[0][1] for i in x],
#    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 999999, 4.9642363])/l_end) * fm[-1][1] for i in x],
    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 9999999, 4.9642363])) for i in x],
#    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 9999999, 9999999])/l_start) for i in x],
#    [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 9999999, 9999999])) for i in x],
    label=r"4.2B model on 12B unique tokens: " + func, 
    color="blue",
    linestyle="dotted"
)


# [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363]
ax.plot(
    np.log10(x), 
    [loss_fn(PARAMS_MAP["4b2"], i) for i in x], 
    label=r"4.2B model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)"
)

lim_s, lim_e = ax.get_ylim()
l_end = scaling_law(PARAMS_MAP["4b2"], fm[-1][0], unique_toks, params)
for ep in [1, 2, 4, 8, 16]:
    t = ep * unique_toks
    #l = (scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), params)/l_start) * fm[0][1]
    #l = (scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), params)/l_end) * fm[-1][1]
    l = scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363])

    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    
    ax.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    ax.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))



ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# %%
func = r"$L(N,D,EP,NP)=E + \frac{A}{(UN + UN * N^* * (1 - e^{(-1*NP/(N^*))}))^\alpha} + \frac{B}{(U + U * EP^* * (1 - e^{(-1*EP/(EP^*))}))^\beta}$"
# Samples: 202; Loss: 0.0231; Only learn EP* & N*; a, b, e, alpha, beta, ep_star, n_star
#params = [6.0073380e+00, 6.0161572e+00, 5.2472854e-01, 3.4000000e-01, 2.8000000e-01, 2.2477303e+00, 3.3332687e+02]
#params = [6.0073380e+00, 6.0161572e+00, 5.2472854e-01, 3.4000000e-01, 2.8000000e-01, 17, 8]
params = [6.007338, 6.016157, 0.52472854, 0.34, 0.28, 508.22855, 287.73526]#323.87842, 236.72693]
params = [6.6229553, 7.5856404, 0.604038, 0.3724021, 0.36468068, 16.257626, 4.9642363]

def scaling_law(N, D, U, params):
    a, b, e, alpha, beta, ep_star, n_star  = params
    A = np.exp(a)
    B = np.exp(b)
    E = np.exp(e)

    ### No Log ###
    EP = np.maximum((D / U) - 1, 0)    
    UN = np.minimum(N,optimal_N(D_to_C(U)))
    NP = np.maximum((N / UN ) - 1, 0)

    L = E + A/(UN + UN*n_star*(1-np.exp(-1*NP/n_star)))**alpha + B / (U + U * ep_star * (1 - np.exp(-1*EP/(ep_star))))**beta
    return L

# %%
import matplotlib.pyplot as plt
import numpy as np

#x = np.linspace(100e5, 1000e9, 50000)
x = np.linspace(1e9, 1000e9, 50000)

unique_toks = 100e6

plt.figure(figsize=(16, 12))


#plt.scatter(np.log10([x[0] for x in fm]), [(x[1]/fm[0][-1])*6 for x in fm], label=r"14M model on $10^8$ unique tokens: " + func)

#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["44m"]])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"44M model on $10^8$ unique tokens: " + func)



#fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["146m"]) and (ut == unique_toks))])
#plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"146M model on $10^8$ unique tokens: " + func)

"""
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["14m"]) and (ut == 100e6)])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"14M model on $10^8$ unique tokens: " + func)
#l_start = scaling_law(PARAMS_MAP["14m"], unique_toks, unique_toks, params)
#plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["14m"], i, min(i, unique_toks), params)/l_start) * fm[0][1] for i in x], label=r"14M model on $10^8$ unique tokens: " + func)

l_end = scaling_law(PARAMS_MAP["14m"], fm[-1][0], unique_toks, params)
plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["14m"], i, min(i, unique_toks), params)/l_end) * fm[-1][1] for i in x], label=r"14M model on $10^8$ unique tokens: " + func)

plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["14m"], i) for i in x], label=r"14M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")

"""

"""
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if m == PARAMS_MAP["83m"]])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"83M model on $10^8$ unique tokens: " + func)
plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["83m"], i, min(i, unique_toks), params) for i in x], label=r"83M model on $10^8$ unique tokens: " + func)
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["83m"], i) for i in x], label=r"83M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
"""

#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["44m"], i, min(i, unique_toks), params) for i in x], label=r"44M model on $10^8$ unique tokens: " + func)
#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["146m"], i, min(i, unique_toks), params) for i in x], label=r"146M model on $10^8$ unique tokens: " + func)



"""
unique_toks = 1.5e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["1b1"]) and (ut == unique_toks)])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"1B1 model on 1.5B unique tokens: " + func, color="red")

l_start = scaling_law(PARAMS_MAP["1b1"], unique_toks, unique_toks, params)

plt.plot(
    np.log10(x), 
    [(scaling_law(PARAMS_MAP["1b1"], i, min(i, unique_toks), params)/l_start) * fm[0][1] for i in x], 
    label=r"1B1 model on 1.5B unique tokens: " + func, 
    color="red",
    #markevery=100,
    #marker='|',
    #markersize=10,
)
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["1b1"], i) for i in x], label=r"1B1 model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
"""



#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["44m"], i) for i in x], label=r"44M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["83m"], i) for i in x], label=r"83M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")
#plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["146m"], i) for i in x], label=r"146M model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")

"""
unique_toks = 12e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["4b2"]) and (ut == unique_toks))])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"4.2B model on 12B unique tokens: " + func, color="blue")
l_end = scaling_law(PARAMS_MAP["4b2"], 84e9, unique_toks, params)
plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["4b2"], i, min(i, unique_toks), params)/l_end) * fm[-1][1] for i in x], label=r"4.2B model on 12B unique tokens: " + func, color="blue")
plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["4b2"], i) for i in x], label=r"4.2B model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)")


unique_toks = 4e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if ((m == PARAMS_MAP["2b8"]) and (ut == unique_toks))])
plt.scatter(np.log10([x[0] for x in fm]), [x[1] for x in fm], label=r"2.8B model on 4B unique tokens: " + func, color="green")

### Normalize via start ###
#l_start = scaling_law(PARAMS_MAP["2b8"], 4e9, 4e9, params)
#plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["2b8"], i, min(i, 4e9), params)/l_start) * fm[0][1] for i in x], label=r"2b8 model on $10^8$ unique tokens: " + func, color="green")

### Normalize via end ###
l_end = scaling_law(PARAMS_MAP["2b8"], 55e9, 4e9, params)
plt.plot(np.log10(x), [(scaling_law(PARAMS_MAP["2b8"], i, min(i, 4e9), params)/l_end) * fm[-1][1] for i in x], label=r"2.8B model on 4B unique tokens: " + func, color="green")

### Do not normalize ###
#plt.plot(np.log10(x), [scaling_law(PARAMS_MAP["2b8"], i, min(i, 4e9), params) for i in x], label=r"2b8 model on $10^8$ unique tokens: " + func, color="green")

plt.plot(np.log10(x), [loss_fn(PARAMS_MAP["2b8"], i) for i in x], label=r"2.8B model on all unique tokens: $L(N,D)=E + \frac{A}{N^\alpha} + \frac{B}{D^\beta}$ (Chinchilla)", color="red")


lim_s, lim_e = plt.ylim()
for ep in [1, 2, 4, 8, 16]:
    t = ep * 4e9
    #l = (scaling_law(PARAMS_MAP["2b8"], t, min(t, 4e9), params)/l_start) * fm[0][1]
    l = (scaling_law(PARAMS_MAP["2b8"], t, min(t, 4e9), params)/l_end) * fm[-1][1]
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')

    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))
"""

lim_s, lim_e = plt.ylim()
unique_toks = 12e9
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["4b2"]) and (ut == 12e9)])
#l_start = scaling_law(PARAMS_MAP["14m"], unique_toks, unique_toks, params)
l_end = scaling_law(PARAMS_MAP["4b2"], fm[-1][0], unique_toks, params)
for ep in [1, 2, 4, 8, 16]:
    t = ep * unique_toks
    #l = (scaling_law(PARAMS_MAP["14m"], t, min(t, unique_toks), params)/l_start) * fm[0][1]
    l = (scaling_law(PARAMS_MAP["4b2"], t, min(t, unique_toks), params)/l_end) * fm[-1][1]
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')

    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))


"""
unique_toks = 100e6
fm = sorted([(t, l) for t, ut, m, l, n in zip(tokens, unique_tokens, model_params, losses, names) if (m == PARAMS_MAP["14m"]) and (ut == 100e6)])
#l_start = scaling_law(PARAMS_MAP["14m"], unique_toks, unique_toks, params)
l_end = scaling_law(PARAMS_MAP["14m"], fm[-1][0], unique_toks, params)

for ep in [1, 2, 4, 8, 16, 32, 64, 128, 256, 512]:
    t = ep * unique_toks
    #l = (scaling_law(PARAMS_MAP["14m"], t, min(t, unique_toks), params)/l_start) * fm[0][1]
    l = (scaling_law(PARAMS_MAP["14m"], t, min(t, unique_toks), params)/l_end) * fm[-1][1]
    # Based on lim_s & lim_e bring l to a range from 0 to 1
    l_scaled = (l - lim_s) / (lim_e - lim_s)
    plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')
    #plt.axvline(x=np.log10(t), ymin=l_scaled-0.01, ymax=l_scaled+0.01, color='black', linestyle='-')

    plt.annotate(f"{ep} Ep.", xy=(np.log10(t)+0.05, l+0.02))
"""




x_ticks = [100e5, 100e6, 100e7, 100e8, 100e9, 100e10, 100e11]
x_ticks_loc = [np.log10(x) for x in x_ticks]
plt.xticks(x_ticks_loc, ["$10^{7}$", "$10^{8}$", "$10^{9}$", "$10^{10}$", "$10^{11}$", "$10^{12}$", "$10^{13}$"])
plt.xlim(np.log10(1.5e9), np.log10(110e10))







#plt.axvline(x=np.log10(unique_toks), color='black', linestyle="--", label='Wall (Tokens are repeated afterwards for Us)')
#plt.axvline(x=np.log10(1.5e9), color='black', linestyle="--")#, label='Wall (Tokens are repeated afterwards for Us)')


plt.legend()
plt.title("Expected validation loss")
plt.xlabel("Training Tokens")
plt.ylabel("Validation Loss")

plt.savefig(f"expvalloss_2b4b.pdf", bbox_inches="tight")
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
